# %% [markdown]
# ### Reading data from files
# #### There are multiple file formats to store data
# - CSV (standard)
# - Feather (Lighter)
# - Parquet (Lightest)

# %%
import pandas as pd

# %%
coffee = pd.read_csv("./Data/coffeeShop.csv")

# %%
coffee
# Out:
#           Date Transaction_ID     Customer_Name               Item Category  \
# 0   2025-08-01         TXN001        John Smith              Latte    Drink
# 1   2025-08-01         TXN002        Mary Jones         Cappuccino    Drink
# 2   2025-08-01         TXN003         David Lee   Blueberry Muffin     Food
# 3   2025-08-02         TXN004        Emma White           Espresso    Drink
# 4   2025-08-02         TXN005       Ethan Brown  Caramel Macchiato    Drink
# 5   2025-08-02         TXN006      Olivia Green   Cheese Croissant     Food
# 6   2025-08-03         TXN007      Liam Johnson          Americano    Drink
# 7   2025-08-03         TXN008     Sophia Taylor              Latte    Drink
# 8   2025-08-03         TXN009       Aiden Clark     Chocolate Cake     Food
# 9   2025-08-04         TXN010    Isabella Adams          Cold Brew    Drink
# 10  2025-08-04         TXN011      James Wilson       Banana Bread     Food
# ...

# %%
coffee.sample(10)
# Out:
#           Date Transaction_ID   Customer_Name               Item Category  \
# 5   2025-08-02         TXN006    Olivia Green   Cheese Croissant     Food
# 8   2025-08-03         TXN009     Aiden Clark     Chocolate Cake     Food
# 9   2025-08-04         TXN010  Isabella Adams          Cold Brew    Drink
# 10  2025-08-04         TXN011    James Wilson       Banana Bread     Food
# 3   2025-08-02         TXN004      Emma White           Espresso    Drink
# 2   2025-08-01         TXN003       David Lee   Blueberry Muffin     Food
# 6   2025-08-03         TXN007    Liam Johnson          Americano    Drink
# 1   2025-08-01         TXN002      Mary Jones         Cappuccino    Drink
# 4   2025-08-02         TXN005     Ethan Brown  Caramel Macchiato    Drink
# 7   2025-08-03         TXN008   Sophia Taylor              Latte    Drink
#
#     Quantity  Price  Total Payment_Method
# 5          1    2.8    2.8           Cash
# 8          1    4.5    4.5           Cash
# ...

# %%
coffee.loc[:0,"Transaction_ID"] = 1

# %%
for i in coffee.iterrows():
    print(i[1],end="\n-----\n")
# Out:
# Date              2025-08-01
# Transaction_ID             1
# Customer_Name     John Smith
# Item                   Latte
# Category               Drink
# Quantity                   2
# Price                    3.5
# Total                    7.0
# Payment_Method          Cash
# Name: 0, dtype: object
# -----
# Date              2025-08-01
# Transaction_ID        TXN002
# Customer_Name     Mary Jones
# Item              Cappuccino
# Category               Drink
# Quantity                   1
# Price                    3.8
# Total                    3.8
# Payment_Method          Card
# Name: 1, dtype: object
# -----
# Date                    2025-08-01
# Transaction_ID              TXN003
# Customer_Name            David Lee
# Item              Blueberry Muffin
# Category                      Food
# Quantity                         3
# Price                          2.5
# Total                          7.5
# Payment_Method                Card
# Name: 2, dtype: object
# -----
# ...
